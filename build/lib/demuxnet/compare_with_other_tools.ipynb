# %%
#compare with MULTI-seq
#https://github.com/chris-mcginnis-ucsf/MULTI-seq

rds_object = readRDS("/home/wuyou/Projects/scRNA-seq/20230506_full_matrix.rds")

# %%
rds_object
# Out:
#   [[ suppressing 32 column names ‘CMO301_AAACCCAAGCGATGCA-1’, ‘CMO301_AAACCCATCCCTTTGG-1’, ‘CMO301_AAACGAAGTGATTCTG-1’ ... ]]
#
#   [[ suppressing 32 column names ‘CMO301_AAACCCAAGCGATGCA-1’, ‘CMO301_AAACCCATCCCTTTGG-1’, ‘CMO301_AAACGAAGTGATTCTG-1’ ... ]]
#
#   [[ suppressing 32 column names ‘CMO301_AAACCCAAGCGATGCA-1’, ‘CMO301_AAACCCATCCCTTTGG-1’, ‘CMO301_AAACGAAGTGATTCTG-1’ ... ]]
# 20761 x 11234 sparse Matrix of class "dgCMatrix"
#
# ENSONIG00000018423 .        .        .        .        .        .        .
# ENSONIG00000033498 .        .        .        .        1.725384 .        .
# ENSONIG00000037808 .        .        .        .        .        .        .
# ENSONIG00000016485 .        .        .        .        .        .        .
# ENSONIG00000018425 .        .        .        .        .        .        .
# ENSONIG00000011691 .        .        .        .        .        .        .
# ENSONIG00000033320 .        .        .        .        .        .        .
# ...

# %%
as.matrix(rds_object)
# Out:
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 1.7 GiB”
#                    CMO301_AAACCCAAGCGATGCA-1 CMO301_AAACCCATCCCTTTGG-1
# ENSONIG00000018423 0                         0
# ENSONIG00000033498 0                         0
# ENSONIG00000037808 0                         0
# ENSONIG00000016485 0                         0
# ENSONIG00000018425 0                         0
# ENSONIG00000011691 0                         0
# ENSONIG00000033320 0                         0
# ENSONIG00000033199 0                         0
# ENSONIG00000035984 0                         0
# ENSONIG00000009366 0                         0
# ENSONIG00000023782 0                         0
# ENSONIG00000028295 0                         0
# ENSONIG00000021243 0                         0
# ENSONIG00000032399 0                         0
# ENSONIG00000043035 0                         0
# ENSONIG00000037321 0                         0
# ...

# %%
# Install MULTI-seq package if not already installed
devtools::install_github('chris-mcginnis-ucsf/MULTI-seq')
# Out:
# ...
# vctrs      (0.6.3  -> 0.6.5   ) [CRAN]
# stringi    (1.7.12 -> 1.8.4   ) [CRAN]
# rlang      (1.1.1  -> 1.1.4   ) [CRAN]
# glue       (1.6.2  -> 1.8.0   ) [CRAN]
# cli        (3.6.1  -> 3.6.3   ) [CRAN]
# Rcpp       (1.0.11 -> 1.0.13-1) [CRAN]
# plyr       (1.8.8  -> 1.8.9   ) [CRAN]
# Rtsne      (0.16   -> 0.17    ) [CRAN]
# stringdist (NA     -> 0.9.12  ) [CRAN]
# Skipping 1 packages not available: ShortRead
#
# Installing 10 packages: vctrs, stringi, rlang, glue, cli, Rcpp, plyr, Rtsne, ShortRead, stringdist
#
# Warning message:
# “package ‘ShortRead’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Warning message in i.p(...):
# “installation of package ‘stringi’ had non-zero exit status”
# Warning message in i.p(...):
# “installation of package ‘rlang’ had non-zero exit status”
# ...

# %%
# Load the package
library(deMULTIplex)

## Pre-process MULTI-seq sample barcode FASTQs
readTable <- MULTIseq.preProcess(R1 = '/path/to/R1.fastq.gz', R2 = '/path/to/R2.fastq.gz', cellIDs = cell.id.vec, cell=c(1,16), umi=c(17,28), tag=c(1,8))
# Out:
# Loading required package: ShortRead
#
# Loading required package: BiocGenerics
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: BiocParallel
#
# Loading required package: Biostrings
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, unname
#
#
# ...

# %%
# Load the package
library(Seurat)
# Out:
# Attaching SeuratObject
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays

# %%
MULTIseqDemux(rds_object)
# Out:
# Error in h(simpleError(msg, call)): error in evaluating the argument 'x' in selecting a method for function 't': no applicable method for 'GetAssayData' applied to an object of class "c('dgCMatrix', 'CsparseMatrix', 'dsparseMatrix', 'generalMatrix', 'dCsparseMatrix', 'AnyMatrix', 'dMatrix', 'sparseMatrix', 'compMatrix', 'Matrix', 'xMatrix', 'mMatrix', 'replValueSp')"
# Traceback:
#
# 1. MULTIseqDemux(rds_object)
# 2. t(x = GetAssayData(object = object, slot = "data", assay = assay))
# 3. GetAssayData(object = object, slot = "data", assay = assay)
# 4. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "no applicable method for 'GetAssayData' applied to an object of class \"c('dgCMatrix', 'CsparseMatrix', 'dsparseMatrix', 'generalMatrix', 'dCsparseMatrix', 'AnyMatrix', 'dMatrix', 'sparseMatrix', 'compMatrix', 'Matrix', 'xMatrix', 'mMatrix', 'replValueSp')\"",
#  .     base::quote(UseMethod(generic = "GetAssayData", object = object)))
# ...

# %%
seurat_obj <- CreateSeuratObject(counts = rds_object)

# %%
str(seurat_obj)
# Out:
# Formal class 'Seurat' [package "SeuratObject"] with 13 slots
#   ..@ assays      :List of 1
#   .. ..$ RNA:Formal class 'Assay' [package "SeuratObject"] with 8 slots
#   .. .. .. ..@ counts       :Formal class 'dgCMatrix' [package "Matrix"] with 6 slots
#   .. .. .. .. .. ..@ i       : int [1:8056784] 67 98 206 222 368 387 424 468 482 491 ...
#   .. .. .. .. .. ..@ p       : int [1:11235] 0 734 1119 2146 3228 4072 4722 5775 6230 7065 ...
#   .. .. .. .. .. ..@ Dim     : int [1:2] 20761 11234
#   .. .. .. .. .. ..@ Dimnames:List of 2
#   .. .. .. .. .. .. ..$ : chr [1:20761] "ENSONIG00000018423" "ENSONIG00000033498" "ENSONIG00000037808" "ENSONIG00000016485" ...
#   .. .. .. .. .. .. ..$ : chr [1:11234] "CMO301_AAACCCAAGCGATGCA-1" "CMO301_AAACCCATCCCTTTGG-1" "CMO301_AAACGAAGTGATTCTG-1" "CMO301_AAACGAATCTGCTCTG-1" ...
#   .. .. .. .. .. ..@ x       : num [1:8056784] 1.35 1.35 1.35 1.35 1.35 ...
#   .. .. .. .. .. ..@ factors : list()
# ...
